# %%
import torch.nn as nn
import torch

# %%
x=torch.randint(10,30,(4,10))

# %%
x.shape
# Out:
# torch.Size([4, 10])

# %%
x
# Out:
# tensor([[29, 25, 12, 28, 16, 25, 22, 17, 25, 28],
#         [22, 12, 11, 12, 18, 11, 17, 16, 29, 13],
#         [17, 26, 21, 20, 14, 20, 27, 11, 22, 14],
#         [19, 19, 28, 29, 18, 14, 26, 23, 15, 12]])

# %%
ha=nn.Embedding(30, 15)

# %%
y=ha(x)

# %%
y.shape
# Out:
# torch.Size([4, 10, 15])

# %%
trans=nn.Transformer(d_model=15,nhead=3,num_encoder_layers=6, num_decoder_layers=6,)

# %%
lul=trans(y,y)

# %%
lul.shape
# Out:
# torch.Size([4, 10, 15])
